# %%
import pandas as pd
import numpy as np
import urllib.request
import matplotlib.pyplot as plt
import time

# %%
from datetime import datetime
ts = int("1616666461")

# if you encounter a "year is out of range" error the timestamp
# may be in milliseconds, try `ts /= 1000` in that case
print(datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# 2021-03-25 10:01:01

# %%
url = "https://tvc4.forexpros.com/9e947eed212d70ba03e313a75eb9a1f5/1616696634/56/56/23/history?symbol=17940&resolution=5&from=1215000000&to=1616696756"
user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'

# url = "http://en.wikipedia.org/wiki/List_of_TCP_and_UDP_port_numbers"
headers={'User-Agent':user_agent,} 

request=urllib.request.Request(url,None,headers) #The assembled request
response = urllib.request.urlopen(request)
data = response.read() # The data u need
Data=pd.read_json(data)
Data
# Out:
#                t             c             o             h             l  \
# 0     1546314300  10844.650391  10882.650391  10884.349609  10844.650391
# 1     1546314600  10835.849609  10840.450195  10850.849609  10834.400391
# 2     1546314900  10850.099609  10835.849609  10850.099609  10835.049805
# 3     1546315200  10837.049805  10850.200195  10850.200195  10835.950195
# 4     1546315500  10839.549805  10837.650391  10841.950195  10835.650391
# ...          ...           ...           ...           ...           ...
# 4995  1554440100  11635.950195  11640.150391  11640.799805  11631.500000
# 4996  1554440400  11640.500000  11636.549805  11641.650391  11633.849609
# 4997  1554440700  11635.750000  11639.849609  11640.849609  11635.049805
# 4998  1554441000  11640.099609  11636.400391  11640.849609  11636.049805
# 4999  1554441300  11641.500000  11640.150391  11642.400391  11637.200195
#
#           v     vo   s
# 0     14432      0  ok
# 1      3623  14432  ok
# ...

# %% [markdown]
# # 1 Minute

# %%
starter=1546314300
FirstFleg=True

while(1):
    if starter==1616666461:
        break
    else:
        url = "https://tvc4.forexpros.com/9e947eed212d70ba03e313a75eb9a1f5/1616696634/56/56/23/history?symbol=17940&resolution=1&from="+str(starter)+"&to=1616666460"
        user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'

        headers={'User-Agent':user_agent,} 

        request=urllib.request.Request(url,None,headers)
        response = urllib.request.urlopen(request)
        
        data = response.read()
        
        buffData=pd.read_json(data)
        starter=np.array(buffData['t'])[-1]+1
        if FirstFleg:
            buffData.to_csv("F.csv",index=False,mode="w")
            FirstFleg=False
        else:
            buffData.to_csv("F.csv",index=False,mode="a",header=False)

# %% [markdown]
# # 5 Minute

# %%
starter=1546314300
FirstFleg=True

while(1):
    if starter==1616666401:
        break
    else:
        url = "https://tvc4.forexpros.com/9e947eed212d70ba03e313a75eb9a1f5/1616696634/56/56/23/history?symbol=17940&resolution=5&from="+str(starter)+"&to=1616666460"
        user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'

        headers={'User-Agent':user_agent,} 

        request=urllib.request.Request(url,None,headers)
        response = urllib.request.urlopen(request)
        
        data = response.read()
        
        buffData=pd.read_json(data)
        starter=np.array(buffData['t'])[-1]+1
        if FirstFleg:
            buffData.to_csv("F_vol.csv",index=False,mode="w")
            FirstFleg=False
        else:
            buffData.to_csv("F_vol.csv",index=False,mode="a",header=False)
